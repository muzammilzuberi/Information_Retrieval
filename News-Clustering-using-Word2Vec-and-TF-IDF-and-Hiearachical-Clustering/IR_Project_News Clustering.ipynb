# %%
import pandas as pd
import re
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
data=pd.read_csv('abcnews-date-text.csv')

# %%
data.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
len(data['headline_text'])
# Out:
# 1103665

# %%
def read_stopwords():  #list all stop words .
  stopword=[]
  f=open("/Users/zohamobin/Documents/Python Codes/IR_Assignment 1 2022/Stopword-List (2).txt","r")
  stopwordlist=f.readlines()
  f.close()
  for l in stopwordlist:
     stopword=stopword+l.split()
  return(stopword)

# %%
data["headline_text"] = data["headline_text"].str.lower()
data["headline_text"] = data['headline_text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
stopword=read_stopwords()
data['headline_text'] = data['headline_text'].apply(lambda x: ' '.join(
    w for w in x.split() if w not in stopword))

# %%
token=''
token= data['headline_text'].apply(word_tokenize)

# %%
data['tokenized'] = data['headline_text'].apply(word_tokenize)
#data.head()

# %%
data.head()
# Out:
#    publish_date                                      headline_text  \
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219           act fire witnesses must aware defamation
# 2      20030219           g calls infrastructure protection summit
# 3      20030219                  air nz staff aust strike pay rise
# 4      20030219         air nz strike affect australian travellers
#
#                                            tokenized
# 0  [aba, decides, against, community, broadcastin...
# 1    [act, fire, witnesses, must, aware, defamation]
# 2     [g, calls, infrastructure, protection, summit]
# 3          [air, nz, staff, aust, strike, pay, rise]
# 4  [air, nz, strike, affect, australian, travellers]

# %%
len(data['tokenized'])
# Out:
# 1103665

# %%
x=data['tokenized'][0][0]

# %%
print(x)
# Out:
# aba

# %%
import nltk

# %%
data['pos_tags'] = data['tokenized'].apply(nltk.tag.pos_tag)

# %%
data.head()
# Out:
#    publish_date                                      headline_text  \
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219           act fire witnesses must aware defamation
# 2      20030219           g calls infrastructure protection summit
# 3      20030219                  air nz staff aust strike pay rise
# 4      20030219         air nz strike affect australian travellers
#
#                                            tokenized  \
# 0  [aba, decides, against, community, broadcastin...
# 1    [act, fire, witnesses, must, aware, defamation]
# 2     [g, calls, infrastructure, protection, summit]
# 3          [air, nz, staff, aust, strike, pay, rise]
# 4  [air, nz, strike, affect, australian, travellers]
#
#                                             pos_tags
# 0  [(aba, JJ), (decides, NNS), (against, IN), (co...
# 1  [(act, NN), (fire, NN), (witnesses, NNS), (mus...
# 2  [(g, NN), (calls, VBZ), (infrastructure, NN), ...
# ...

# %%
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
data['wordnet_pos'] = data['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
porter = PorterStemmer()

# %%
data['Stemmed']= data['tokenized'].apply(lambda x : [porter.stem(y) for y in x])

# %%
wnl = WordNetLemmatizer() #isko remove and wordnet pos_tags coz now stemming working
data['lemmatized'] = data['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

# %%
data.head()
# Out:
#    publish_date                                      headline_text  \
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219           act fire witnesses must aware defamation
# 2      20030219           g calls infrastructure protection summit
# 3      20030219                  air nz staff aust strike pay rise
# 4      20030219         air nz strike affect australian travellers
#
#                                            tokenized  \
# 0  [aba, decides, against, community, broadcastin...
# 1    [act, fire, witnesses, must, aware, defamation]
# 2     [g, calls, infrastructure, protection, summit]
# 3          [air, nz, staff, aust, strike, pay, rise]
# 4  [air, nz, strike, affect, australian, travellers]
#
#                                             pos_tags  \
# 0  [(aba, JJ), (decides, NNS), (against, IN), (co...
# 1  [(act, NN), (fire, NN), (witnesses, NNS), (mus...
# 2  [(g, NN), (calls, VBZ), (infrastructure, NN), ...
# ...

# %%
data['lemmatized']
# Out:
# 0          [aba, decides, against, community, broadcastin...
# 1              [act, fire, witness, must, aware, defamation]
# 2              [g, call, infrastructure, protection, summit]
# 3                  [air, nz, staff, aust, strike, pay, rise]
# 4           [air, nz, strike, affect, australian, traveller]
#                                  ...
# 1103660    [ash, smiths, warner, near, miss, liven, box, ...
# 1103661           [timelapse, brisbane, new, year, firework]
# 1103662                  [what, 2017, meant, kid, australia]
# 1103663      [what, papodopoulos, meeting, may, mean, ausus]
# 1103664    [who, george, papadopoulos, former, trump, cam...
# Name: lemmatized, Length: 1103665, dtype: object

# %%
data['Stemmed']
# Out:
# 0           [aba, decid, against, commun, broadcast, licenc]
# 1                        [act, fire, wit, must, awar, defam]
# 2                  [g, call, infrastructur, protect, summit]
# 3                  [air, nz, staff, aust, strike, pay, rise]
# 4              [air, nz, strike, affect, australian, travel]
#                                  ...
# 1103660    [ash, smith, warner, near, miss, liven, box, d...
# 1103661             [timelaps, brisban, new, year, firework]
# 1103662                  [what, 2017, meant, kid, australia]
# 1103663           [what, papodopoulo, meet, may, mean, ausu]
# 1103664    [who, georg, papadopoulo, former, trump, campa...
# Name: Stemmed, Length: 1103665, dtype: object

# %%
import pandas as pd

# %%
df2=pd.read_csv('abcnews-date-text.csv')

# %%
df2
# Out:
#          publish_date                                      headline_text
# 0            20030219  aba decides against community broadcasting lic...
# 1            20030219     act fire witnesses must be aware of defamation
# 2            20030219     a g calls for infrastructure protection summit
# 3            20030219           air nz staff in aust strike for pay rise
# 4            20030219      air nz strike to affect australian travellers
# ...               ...                                                ...
# 1103660      20171231  the ashes smiths warners near miss liven up bo...
# 1103661      20171231            timelapse: brisbanes new year fireworks
# 1103662      20171231           what 2017 meant to the kids of australia
# 1103663      20171231   what the papodopoulos meeting may mean for ausus
# 1103664      20171231  who is george papadopoulos the former trump ca...
#
# [1103665 rows x 2 columns]

# %%
df2['lemmatized'] = data['lemmatized']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lemmatized'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-659f5c2ec623> in <module>
# ...

# %%
df2.head()
# Out:
#    publish_date                                      headline_text  \
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers
#
#                                             Stemmed
# 0  [aba, decid, against, commun, broadcast, licenc]
# 1               [act, fire, wit, must, awar, defam]
# 2         [g, call, infrastructur, protect, summit]
# 3         [air, nz, staff, aust, strike, pay, rise]
# 4     [air, nz, strike, affect, australian, travel]

# %%
df2.to_csv('output.csv', index=False) #yahan par meine preprocessing karke csv mein daaldiya bhejdeyti hoon abhi yes

# %%
import networkx as nx
import re 
import itertools
import operator
import copy
import heapq
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag
import string
from nltk.corpus import stopwords
import re
import matplotlib.pyplot as plt
from networkx import k_core
from networkx import core_number
import spacy
import sys
import numpy as np
import textacy
from nltk.tokenize import word_tokenize,wordpunct_tokenize
import networkx.drawing
import textacy.keyterms
from networkx import common_neighbors
import pandas as pd
from collections import OrderedDict

# %%
import itertools

# %%
# !pip install textacy
# Out:
# ...
#      |████████████████████████████████| 208 kB 822 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 641 kB/s eta 0:00:01
# ...

# %%
import textacy

# %%
data['x']= data['tokenized'].apply(preprocess.unpack_contractions(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d888e535242> in <module>
# ----> 1 data['x']= data['tokenized'].apply(preprocess.unpack_contractions(text))
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
d2=pd.read_csv('output.csv')

# %%
d2.head()
# Out:
#    publish_date                                      headline_text  \
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers
#
#                                              Stemmed
# 0  ['aba', 'decid', 'against', 'commun', 'broadca...
# 1    ['act', 'fire', 'wit', 'must', 'awar', 'defam']
# 2  ['g', 'call', 'infrastructur', 'protect', 'sum...
# 3  ['air', 'nz', 'staff', 'aust', 'strike', 'pay'...
# 4  ['air', 'nz', 'strike', 'affect', 'australian'...

# %%
global text

# %%
text=d2.Series(df.A.values,index=df.B).to_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-854ddb370ca6> in <module>
# ----> 1 text=d2.Series(df.A.values,index=df.B).to_dict()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
text=d2['Stemmed'].to_list()

# %%
type(text)
# Out:
# list

# %%
text
# Out:
# ["['aba', 'decid', 'against', 'commun', 'broadcast', 'licenc']",
#  "['act', 'fire', 'wit', 'must', 'awar', 'defam']",
#  "['g', 'call', 'infrastructur', 'protect', 'summit']",
#  "['air', 'nz', 'staff', 'aust', 'strike', 'pay', 'rise']",
#  "['air', 'nz', 'strike', 'affect', 'australian', 'travel']",
#  "['ambiti', 'olsson', 'win', 'tripl', 'jump']",
#  "['antic', 'delight', 'with', 'record', 'break', 'barca']",
#  "['aussi', 'qualifi', 'stosur', 'wast', 'four', 'memphi', 'match']",
#  "['aust', 'address', 'un', 'secur', 'council', 'over', 'iraq']",
#  "['australia', 'lock', 'into', 'war', 'timet', 'opp']",
#  "['australia', 'contribut', '10', 'million', 'aid', 'iraq']",
#  "['barca', 'take', 'record', 'robson', 'celebr', 'birthday']",
#  "['bathhous', 'plan', 'move', 'ahead']",
#  "['big', 'hope', 'launceston', 'cycl', 'championship']",
#  "['big', 'plan', 'boost', 'paroo', 'water', 'suppli']",
#  "['blizzard', 'buri', 'unit', 'state', 'bill']",
# ...

# %%
count=0
for i in d2.['Stemmed']:
    count=count+1
# Out:
#   File "<ipython-input-14-979404ff6c7c>", line 2
#     for i in d2.['Stemmed']:
#                 ^
# SyntaxError: invalid syntax

# %%
global extended_text

# %%
def terms_to_graph_sents(text, w,stopping_end_of_line=0):
    from_to = {}
    if(not stopping_end_of_line):
        extended_text=[]
        for sublist in text:
            extended_text.extend(sublist)
        text=[extended_text]
    for k,sents in enumerate(text):
        len_sents=len(sents)

        # create initial complete graph (first w terms)
        terms_temp = sents[0:min(w,len_sents)]
        indexes = list(itertools.combinations(range(min(w,len_sents)), r=2))
        new_edges = []
        for my_tuple in indexes:
            new_edges.append(tuple([terms_temp[i] for i in my_tuple]))

        for new_edge in new_edges:
            if new_edge in from_to:
                from_to[new_edge] += 1
            else:
                from_to[new_edge] = 1

        if(w<=len_sents):
            # then iterate over the remaining terms
            for i in range(w, len_sents):
                considered_term = sents[i] # term to consider
                terms_temp = sents[(i-w+1):(i+1)] # all terms within sliding window

                # edges to try
                candidate_edges = []
                for p in range(w-1):
                    candidate_edges.append((terms_temp[p],considered_term))

                for try_edge in candidate_edges:

                    if try_edge[1] != try_edge[0]:
                    # if not self-edge

                        # if edge has already been seen, update its weight
                        if try_edge in from_to:
                            from_to[try_edge] += 1

                        # if edge has never been seen, create it and assign it a unit weight     
                        else:
                            from_to[try_edge] = 1
    
    return(from_to)

# %%
tuples_words_sents_unweighted=list(terms_to_graph_sents(text, w=5,stopping_end_of_line=1).keys())
tuples_words_sents_weighted=terms_to_graph_sents(text, w=5,stopping_end_of_line=0)

# %%
print("tuples unweighted \n")
tuples_words_sents_unweighted[:10]
# Out:
# tuples unweighted
# [('[', "'"),
#  ('[', 'a'),
#  ('[', 'b'),
#  ("'", 'a'),
#  ("'", 'b'),
#  ('a', 'b'),
#  ('a', 'a'),
#  ('b', 'a'),
#  ('a', "'"),
#  ('b', "'")]

# %%
tuples_words_sents_weighted
# Out:
# {('[', "'"): 1163533,
#  ('[', 'a'): 359957,
#  ('[', 'b'): 103517,
#  ("'", 'a'): 2754180,
#  ("'", 'b'): 992691,
#  ('a', 'b'): 117289,
#  ('a', 'a'): 1,
#  ('b', 'a'): 223004,
#  ('a', "'"): 2381221,
#  ('b', "'"): 469432,
#  ('a', ','): 1493307,
#  ('b', ','): 209870,
#  ("'", ','): 5298642,
#  ('b', ' '): 114336,
#  ('a', ' '): 803556,
#  ("'", ' '): 5122066,
#  (',', ' '): 5104945,
#  (',', "'"): 5122741,
#  (' ', "'"): 5266562,
#  ("'", 'd'): 1103316,
#  (',', 'd'): 299274,
#  (' ', 'd'): 447250,
#  (',', 'e'): 893040,
#  (' ', 'e'): 1245660,
#  ("'", 'e'): 2393480,
#  ('d', 'e'): 349175,
#  (' ', 'c'): 779573,
#  ("'", 'c'): 1718865,
#  ('d', 'c'): 65776,
#  ('e', 'c'): 266800,
#  ("'", 'i'): 1771840,
#  ('d', 'i'): 225809,
#  ('e', 'i'): 356725,
#  ('c', 'i'): 295229,
#  ('e', 'd'): 240599,
#  ('c', 'd'): 74913,
#  ('i', 'd'): 197514,
#  ('e', "'"): 2729612,
#  ('c', "'"): 1012149,
#  ('i', "'"): 2330546,
#  ('d', "'"): 1274433,
#  ('c', ','): 498870,
# ...

# %%
# !pip install library
# Out:
# ...
#   Created wheel for library: filename=Library-0.0.0-py3-none-any.whl size=2087 sha256=009ce5715c9b25befa9ec2205cb897d9151cde23e056f663e25009223a36ce88
#   Stored in directory: /Users/zohamobin/Library/Caches/pip/wheels/ad/b3/c5/e316adfd11c210f73253daa770c7c60f0cb32c8843cdc84cb4
# Successfully built library
# ...

# %%
#import os
#os.chdir() # to change working directory to where functions live
# import custom functions
from library import clean_text_simple, terms_to_graph, unweighted_k_core
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-9d0154590c95> in <module>
#       2 #os.chdir() # to change working directory to where functions live
#       3 # import custom functions
# ----> 4 from library import clean_text_simple, terms_to_graph, unweighted_k_core
#
# ModuleNotFoundError: No module named 'library'

# %%
def terms_to_graph(terms, w):
    '''This function returns a directed, weighted igraph from a list of terms (the tokens from the pre-processed text) e.g., ['quick','brown','fox'].
    Edges are weighted based on term co-occurrence within a sliding window of fixed size 'w'.
    '''
    
    from_to = {}
    
    # create initial complete graph (first w terms)
    terms_temp = terms[0:w]
    indexes = list(itertools.combinations(range(w), r=2))
    
    new_edges = []
    
    for my_tuple in indexes:
        new_edges.append(tuple([terms_temp[i] for i in my_tuple]))
    
    for new_edge in new_edges:
        if new_edge in from_to:
            from_to[new_edge] += 1
        else:
            from_to[new_edge] = 1

    # then iterate over the remaining terms
    for i in range(w, len(terms)):
        considered_term = terms[i] # term to consider
        terms_temp = terms[(i-w+1):(i+1)] # all terms within sliding window
        
        # edges to try
        candidate_edges = []
        for p in range(w-1):
            candidate_edges.append((terms_temp[p],considered_term))
    
        for try_edge in candidate_edges:
            
            if try_edge[1] != try_edge[0]:
            # if not self-edge
            
                # if edge has already been seen, update its weight
                if try_edge in from_to:
                    from_to[try_edge] += 1
                                   
                # if edge has never been seen, create it and assign it a unit weight     
                else:
                    from_to[try_edge] = 1
    
    # create empty graph
    g = igraph.Graph(directed=True)
    
    # add vertices
    g.add_vertices(sorted(set(terms)))
    
    # add edges, direction is preserved since the graph is directed
    g.add_edges(from_to.keys())
    
    # set edge and vertex weights
    #print (g.strength(weights=g.es["weight"]))
    g.es['weight'] = from_to.values() # based on co-occurence within sliding window
    g.vs['weight'] = g.strength() # weighted degree
    
    return(g)

# %%
def core_dec(g,weighted):
    '''(un)weighted k-core decomposition'''
    # work on clone of g to preserve g 
    gg = copy.deepcopy(g)
    if not weighted:
        gg.vs['weight'] = gg.strength() # overwrite the 'weight' vertex attribute with the unweighted degrees
    # initialize dictionary that will contain the core numbers
    cores_g = dict(zip(gg.vs['name'],[0]*len(gg.vs)))
    
    while len(gg.vs) > 0:
        # find index of lowest degree vertex
        min_degree = min(gg.vs['weight'])
        index_top = gg.vs['weight'].index(min_degree)
        name_top = gg.vs[index_top]['name']
        # get names of its neighbors
        neighbors = gg.vs[gg.neighbors(index_top)]['name']
        # exclude self-edges
        neighbors = [elt for elt in neighbors if elt!=name_top]
        # set core number of lowest degree vertex as its degree
        cores_g[name_top] = min_degree
        # delete top vertex and its incident edges
        gg.delete_vertices(index_top)
        
        if neighbors:
            if weighted: 
                new_degrees = gg.strength(weights=gg.es['weight'])
            else:
                new_degrees = gg.strength()
            # iterate over neighbors of top element
            for neigh in neighbors:
                index_n = gg.vs['name'].index(neigh)
                gg.vs[index_n]['weight'] = max(min_degree,new_degrees[index_n])  
        
    return(cores_g)

# %%
def accuracy_metrics(candidate, truth):
    
    # true positives ('hits') are both in candidate and in truth
    tp = len(set(candidate).intersection(truth))
    
    # false positives ('false alarms') are in candidate but not in truth
    fp = len([element for element in candidate if element not in truth])
    
    # false negatives ('misses') are in truth but not in candidate
    fn = len([element for element in truth if element not in candidate])
    
    # precision
    prec = round(float(tp)/(tp+fp),5)
    
    # recall
    rec = round(float(tp)/(tp+fn),5)
    
    if prec+rec != 0:
        # F1 score
        f1 = round(2 * float(prec*rec)/(prec+rec),5)
    else:
        f1 = 0
       
    return (prec, rec, f1)

# %%
import re 
import itertools
import operator
import copy
import igraph
import heapq
import nltk

# %%
# !pip install igraph
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 821 kB/s eta 0:00:01
# ...

# %%
g = terms_to_graph(text, w=4)

# %%
# number of edges
print(len(g.es))
# Out:
# 3295882

# %%
# the number of nodes should be equal to the number of unique terms
len(g.vs) == len(set(text))
# Out:
# True

# %%
edge_weights = []
for edge in g.es:
    source = g.vs[edge.source]['name']
    target = g.vs[edge.target]['name']
    weight = edge['weight']
    edge_weights.append([source, target, weight])

# %%
for w in range(2,11):
    g = terms_to_graph(text, w)
    print(g.density())
# Out:
# 9.533115815002486e-07
# 1.9066361826239053e-06
# 2.8607428291269302e-06
# 3.815369392591378e-06
# 4.770272840046966e-06
# 5.725299539937483e-06
# 6.680447756313141e-06
# 7.635636767508809e-06
# 8.590907368344502e-06

# %%
core_numbers = core_dec(g,weighted)
print(core_numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-0bb3af1de19d> in <module>
# ----> 1 core_numbers = core_dec(g,weighted)
#       2 print(core_numbers)
#
# NameError: name 'weighted' is not defined

# %%
print(dict(zip(g.vs["name"],g.coreness())))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
max_c_n = max(core_numbers.values())
keywords = [kwd for kwd, c_n in core_numbers.iteritems() if c_n == max_c_n]
print(keywords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-cf95be118582> in <module>
# ----> 1 max_c_n = max(core_numbers.values())
#       2 keywords = [kwd for kwd, c_n in core_numbers.iteritems() if c_n == max_c_n]
#       3 print(keywords)
#
# NameError: name 'core_numbers' is not defined
